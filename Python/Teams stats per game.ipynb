# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import os

# %%
# Spécifiez le chemin complet du répertoire contenant votre fichier CSV
chemin_du_repertoire = 'C:\\Users\\yvann\\OneDrive\\Documents\\Jedha\\CERTIFICATION BLOC 6'

# Changez le répertoire de travail
os.chdir(chemin_du_repertoire)

# Maintenant, vous pouvez lire le fichier CSV
df6 = pd.read_csv("Team_Stats_Per_Game.csv")
print(df6)
# Out:
#       season   lg                     team abbreviation  playoffs     g  \
# 0       2024  NBA            Atlanta Hawks          ATL     False  82.0
# 1       2024  NBA           Boston Celtics          BOS      True  82.0
# 2       2024  NBA            Brooklyn Nets          BRK     False  82.0
# 3       2024  NBA            Chicago Bulls          CHI     False  82.0
# 4       2024  NBA        Charlotte Hornets          CHO     False  82.0
# ...      ...  ...                      ...          ...       ...   ...
# 1840    1947  BAA  Providence Steamrollers          PRO     False  60.0
# 1841    1947  BAA        St. Louis Bombers          STB      True  61.0
# 1842    1947  BAA          Toronto Huskies          TRH     False  60.0
# 1843    1947  BAA      Washington Capitols          WSC      True  60.0
# 1844    1947  BAA           League Average          NaN     False  60.0
#
#       mp_per_game  fg_per_game  fga_per_game  fg_percent  ...  ft_percent  \
# ...

# %%
df6.head()
# Out:
#    season   lg               team abbreviation  playoffs     g  mp_per_game  \
# 0    2024  NBA      Atlanta Hawks          ATL     False  82.0        242.1
# 1    2024  NBA     Boston Celtics          BOS      True  82.0        241.8
# 2    2024  NBA      Brooklyn Nets          BRK     False  82.0        241.5
# 3    2024  NBA      Chicago Bulls          CHI     False  82.0        243.7
# 4    2024  NBA  Charlotte Hornets          CHO     False  82.0        240.6
#
#    fg_per_game  fga_per_game  fg_percent  ...  ft_percent  orb_per_game  \
# 0         43.0          92.5       0.465  ...       0.797          12.5
# 1         43.9          90.2       0.487  ...       0.807          10.7
# 2         40.7          89.1       0.456  ...       0.756          11.4
# 3         42.0          89.5       0.470  ...       0.791          11.2
# 4         40.0          87.0       0.460  ...       0.786           9.3
#
#    drb_per_game  trb_per_game  ast_per_game  stl_per_game  blk_per_game  \
# ...

# %%
df6.drop(['abbreviation', 'mp_per_game', 'lg'], axis=1, inplace=True)
df6.head()
# Out:
#    season               team  playoffs     g  fg_per_game  fga_per_game  \
# 0    2024      Atlanta Hawks     False  82.0         43.0          92.5
# 1    2024     Boston Celtics      True  82.0         43.9          90.2
# 2    2024      Brooklyn Nets     False  82.0         40.7          89.1
# 3    2024      Chicago Bulls     False  82.0         42.0          89.5
# 4    2024  Charlotte Hornets     False  82.0         40.0          87.0
#
#    fg_percent  x3p_per_game  x3pa_per_game  x3p_percent  ...  ft_percent  \
# 0       0.465          13.7           37.7        0.364  ...       0.797
# 1       0.487          16.5           42.5        0.388  ...       0.807
# 2       0.456          13.3           36.7        0.362  ...       0.756
# 3       0.470          11.5           32.1        0.358  ...       0.791
# 4       0.460          12.1           34.0        0.355  ...       0.786
#
#    orb_per_game  drb_per_game  trb_per_game  ast_per_game  stl_per_game  \
# ...

# %%
df6.to_csv('Teams stats per game.csv', index=False)

# %%
df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1845 entries, 0 to 1844
# Data columns (total 25 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   season         1845 non-null   int64
#  1   team           1845 non-null   object
#  2   playoffs       1845 non-null   bool
#  3   g              1844 non-null   float64
#  4   fg_per_game    1844 non-null   float64
#  5   fga_per_game   1844 non-null   float64
#  6   fg_percent     1844 non-null   float64
#  7   x3p_per_game   1402 non-null   float64
#  8   x3pa_per_game  1402 non-null   float64
#  9   x3p_percent    1402 non-null   float64
#  10  x2p_per_game   1844 non-null   float64
#  11  x2pa_per_game  1844 non-null   float64
#  12  x2p_percent    1844 non-null   float64
#  13  ft_per_game    1844 non-null   float64
#  14  fta_per_game   1844 non-null   float64
#  15  ft_percent     1844 non-null   float64
#  16  orb_per_game   1515 non-null   float64
# ...

# %%
df6.isnull().sum()
# Out:
# season             0
# team               0
# playoffs           0
# g                  1
# fg_per_game        1
# fga_per_game       1
# fg_percent         1
# x3p_per_game     443
# x3pa_per_game    443
# x3p_percent      443
# x2p_per_game       1
# x2pa_per_game      1
# x2p_percent        1
# ft_per_game        1
# fta_per_game       1
# ft_percent         1
# orb_per_game     330
# drb_per_game     330
# trb_per_game      53
# ast_per_game       1
# stl_per_game     389
# blk_per_game     389
# tov_per_game     318
# pf_per_game        1
# pts_per_game       1
# dtype: int64

# %%
nulls = pd.isnull(df6)
nulls = nulls.sum()
nulls[nulls>0]
# Out:
# g                  1
# fg_per_game        1
# fga_per_game       1
# fg_percent         1
# x3p_per_game     443
# x3pa_per_game    443
# x3p_percent      443
# x2p_per_game       1
# x2pa_per_game      1
# x2p_percent        1
# ft_per_game        1
# fta_per_game       1
# ft_percent         1
# orb_per_game     330
# drb_per_game     330
# trb_per_game      53
# ast_per_game       1
# stl_per_game     389
# blk_per_game     389
# tov_per_game     318
# pf_per_game        1
# pts_per_game       1
# dtype: int64

# %%
df6['season'] = pd.to_datetime(df6['season'], format='%Y')

# %%
colonnes_stats = ['g', 'fg_per_game', 'fga_per_game', 'fg_percent', 'x3p_per_game', 'x3pa_per_game',
                  'x3p_percent', 'x2p_per_game', 'x2pa_per_game', 'x2p_percent', 'ft_per_game', 'fta_per_game',
                  'ft_percent', 'orb_per_game', 'drb_per_game', 'trb_per_game', 'ast_per_game', 'stl_per_game',
                  'blk_per_game', 'tov_per_game', 'pf_per_game', 'pts_per_game']

moyenne_stats_depuis_1947 = df6[df6['team'] == 'League Average'][colonnes_stats].mean().round(2)
print("Moyenne des stats de la league depuis 1947:")
print(moyenne_stats_depuis_1947)
# Out:
# Moyenne des stats de la league depuis 1947:
# g                 78.55
# fg_per_game       39.63
# fga_per_game      89.61
# fg_percent         0.44
# x3p_per_game       4.86
# x3pa_per_game     13.95
# x3p_percent        0.33
# x2p_per_game      36.61
# x2pa_per_game     80.95
# x2p_percent        0.46
# ft_per_game       21.60
# fta_per_game      28.99
# ft_percent         0.75
# orb_per_game      13.28
# drb_per_game      31.17
# trb_per_game      49.27
# ast_per_game      22.54
# stl_per_game       8.22
# blk_per_game       5.05
# tov_per_game      16.42
# pf_per_game       23.71
# pts_per_game     103.87
# dtype: float64

# %%
colonnes_stats = ['g', 'fg_per_game', 'fga_per_game', 'fg_percent', 'x3p_per_game', 'x3pa_per_game',
                  'x3p_percent', 'x2p_per_game', 'x2pa_per_game', 'x2p_percent', 'ft_per_game', 'fta_per_game',
                  'ft_percent', 'orb_per_game', 'drb_per_game', 'trb_per_game', 'ast_per_game', 'stl_per_game',
                  'blk_per_game', 'tov_per_game', 'pf_per_game', 'pts_per_game']

moyenne_stats_depuis_1947 = df6[df6['team'] == 'Chicago Bulls'][colonnes_stats].mean().round(2)
print("Moyenne des stats des CHi depuis 1947:")
print(moyenne_stats_depuis_1947)
# Out:
# Moyenne des stats des CHi depuis 1947:
# g                 80.69
# fg_per_game       39.52
# fga_per_game      86.25
# fg_percent         0.46
# x3p_per_game       5.05
# x3pa_per_game     14.34
# x3p_percent        0.33
# x2p_per_game      35.59
# x2pa_per_game     75.13
# x2p_percent        0.48
# ft_per_game       19.61
# fta_per_game      25.90
# ft_percent         0.76
# orb_per_game      12.87
# drb_per_game      31.01
# trb_per_game      45.34
# ast_per_game      23.72
# stl_per_game       7.98
# blk_per_game       4.81
# tov_per_game      16.01
# pf_per_game       22.37
# pts_per_game     102.57
# dtype: float64

# %%
# Choix de la franchise
nom_franchise = "San Antonio Spurs"

colonnes_stats = ['fg_per_game', 'fga_per_game', 'fg_percent', 'x3p_per_game', 'x3pa_per_game',
                  'x3p_percent', 'x2p_per_game', 'x2pa_per_game', 'x2p_percent', 'ft_per_game', 'fta_per_game',
                  'ft_percent', 'orb_per_game', 'drb_per_game', 'trb_per_game', 'ast_per_game', 'stl_per_game',
                  'blk_per_game', 'tov_per_game', 'pf_per_game', 'pts_per_game']

filtered_data = df6[df6['season'].dt.year >= 1980]

# Stats moyennes de la ligue depuis 1947
League = df6[df6['team'] == 'League Average'][colonnes_stats].mean().round(2)
# Stats de l'équipe sélectionnée 
Franchise = df6[df6['team'] == nom_franchise][colonnes_stats].mean().round(2)

# Concaténer les deux séries résultantes côte à côte
result = pd.concat([League, Franchise], axis=1)

# Ajout du nom de la franchise
nouveau_nom_franchise = f'"{nom_franchise}"'
result.columns = ['League', nouveau_nom_franchise]

print(result)
# Out:
#                League  "San Antonio Spurs"
# fg_per_game      0.50                 0.53
# fga_per_game     0.38                 0.37
# fg_percent       0.44                 0.51
# x3p_per_game     0.31                 0.30
# x3pa_per_game    0.32                 0.29
# x3p_percent      0.71                 0.70
# x2p_per_game     0.45                 0.48
# x2pa_per_game    0.52                 0.53
# x2p_percent      0.41                 0.46
# ft_per_game      0.43                 0.42
# fta_per_game     0.44                 0.44
# ft_percent       0.54                 0.53
# orb_per_game     0.40                 0.37
# drb_per_game     0.33                 0.41
# trb_per_game     0.45                 0.50
# ast_per_game     0.50                 0.55
# stl_per_game     0.36                 0.32
# blk_per_game     0.42                 0.51
# tov_per_game     0.39                 0.36
# pf_per_game      0.47                 0.41
# pts_per_game     0.49                 0.52

# %%
df6.dropna(inplace=True)
df_cleaned = df6.dropna()

# %%
nulls = pd.isnull(df6)
nulls
# Out:
#       season   team  playoffs      g  fg_per_game  fga_per_game  fg_percent  \
# 0      False  False     False  False        False         False       False
# 1      False  False     False  False        False         False       False
# 2      False  False     False  False        False         False       False
# 3      False  False     False  False        False         False       False
# 4      False  False     False  False        False         False       False
# ...      ...    ...       ...    ...          ...           ...         ...
# 1449   False  False     False  False        False         False       False
# 1450   False  False     False  False        False         False       False
# 1452   False  False     False  False        False         False       False
# 1453   False  False     False  False        False         False       False
# 1455   False  False     False  False        False         False       False
#
# ...

# %%
removed_columns = ["season", "lg", "team","playoffs","g"]
selected_columns = df6.columns[~df6.columns.isin(removed_columns)]

# %%
df6.insert(df6.columns.get_loc('playoffs') + 1, 'target','valeur_par_defaut')

# %%
def add_target(team):
    team["target"] = team["playoffs"].shift(-1)
    return team

df6 = df6.groupby("team", group_keys=False).apply(add_target)

# %% [markdown]
# CHANGEMENTS

# %%
from sklearn.model_selection import TimeSeriesSplit
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.linear_model import RidgeClassifier

rr = RidgeClassifier(alpha=1)
split = TimeSeriesSplit(n_splits=3)
sfs = SequentialFeatureSelector(rr, n_features_to_select=30, direction='forward',cv=split)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
df6[selected_columns] = scaler.fit_transform(df6[selected_columns])

# %%
df6
# Out:
#          season                     team  playoffs target     g  fg_per_game  \
# 0    2024-01-01            Atlanta Hawks     False  False  82.0     0.689266
# 1    2024-01-01           Boston Celtics      True  False  82.0     0.740113
# 2    2024-01-01            Brooklyn Nets     False  False  82.0     0.559322
# 3    2024-01-01            Chicago Bulls     False  False  82.0     0.632768
# 4    2024-01-01        Charlotte Hornets     False  False  82.0     0.519774
# ...         ...                      ...       ...    ...   ...          ...
# 1449 1974-01-01        San Antonio Spurs      True    NaN  84.0     0.508475
# 1450 1974-01-01  San Diego Conquistadors      True    NaN  84.0     0.887006
# 1452 1974-01-01               Utah Stars      True    NaN  84.0     0.672316
# 1453 1974-01-01         Virginia Squires      True    NaN  84.0     0.564972
# 1455 1974-01-01           League Average     False    NaN  84.0     0.683616
#
# ...

# %%
df6["playoffs"].value_counts()
# Out:
# playoffs
# True     701
# False    630
# Name: count, dtype: int64

# %%
df6["target"].value_counts()
# Out:
# target
# True     687
# False    593
# Name: count, dtype: int64

# %%
df6[df6["team"] == "Chicago Bulls"]
# Out:
#          season           team  playoffs target     g  fg_per_game  \
# 3    2024-01-01  Chicago Bulls     False  False  82.0     0.632768
# 34   2023-01-01  Chicago Bulls     False   True  82.0     0.661017
# 65   2022-01-01  Chicago Bulls      True  False  82.0     0.615819
# 96   2021-01-01  Chicago Bulls     False  False  72.0     0.644068
# 127  2020-01-01  Chicago Bulls     False  False  65.0     0.497175
# 158  2019-01-01  Chicago Bulls     False  False  82.0     0.508475
# 189  2018-01-01  Chicago Bulls     False   True  82.0     0.446328
# 220  2017-01-01  Chicago Bulls      True  False  82.0     0.440678
# 251  2016-01-01  Chicago Bulls     False   True  82.0     0.440678
# 282  2015-01-01  Chicago Bulls      True   True  82.0     0.327684
# 314  2014-01-01  Chicago Bulls      True   True  82.0     0.220339
# 345  2013-01-01  Chicago Bulls      True   True  82.0     0.276836
# 375  2012-01-01  Chicago Bulls      True   True  66.0     0.372881
# ...

# %%
df6["target"][pd.isnull(df6["target"])]
# Out:
# 328     NaN
# 343     NaN
# 485     NaN
# 576     NaN
# 591     NaN
# 667     NaN
# 693     NaN
# 828     NaN
# 885     NaN
# 887     NaN
# 1045    NaN
# 1048    NaN
# 1060    NaN
# 1071    NaN
# 1150    NaN
# 1167    NaN
# 1256    NaN
# 1276    NaN
# 1277    NaN
# 1278    NaN
# 1279    NaN
# 1281    NaN
# 1282    NaN
# 1283    NaN
# 1285    NaN
# 1286    NaN
# 1287    NaN
# 1288    NaN
# 1289    NaN
# 1290    NaN
# 1291    NaN
# 1292    NaN
# 1294    NaN
# 1295    NaN
# 1296    NaN
# 1297    NaN
# 1389    NaN
# 1403    NaN
# 1411    NaN
# 1421    NaN
# 1431    NaN
# 1435    NaN
# 1438    NaN
# 1440    NaN
# 1443    NaN
# 1444    NaN
# 1449    NaN
# 1450    NaN
# 1452    NaN
# 1453    NaN
# 1455    NaN
# Name: target, dtype: object

# %%
df6["target"].value_counts()
# Out:
# target
# True     687
# False    593
# Name: count, dtype: int64

# %%
df_clean = df6.dropna()
mean_value = df6['target'].mean()
df6['target'].fillna(mean_value, inplace=True)

# %%
df6.isnull().sum()
# Out:
# season           0
# team             0
# playoffs         0
# target           0
# g                0
# fg_per_game      0
# fga_per_game     0
# fg_percent       0
# x3p_per_game     0
# x3pa_per_game    0
# x3p_percent      0
# x2p_per_game     0
# x2pa_per_game    0
# x2p_percent      0
# ft_per_game      0
# fta_per_game     0
# ft_percent       0
# orb_per_game     0
# drb_per_game     0
# trb_per_game     0
# ast_per_game     0
# stl_per_game     0
# blk_per_game     0
# tov_per_game     0
# pf_per_game      0
# pts_per_game     0
# dtype: int64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# Séparer les données en ensemble d'entraînement et ensemble de test
X_train, X_test, y_train, y_test = train_test_split(df6[selected_columns], df6["target"], test_size=0.2, random_state=42)

# Créer un modèle de régression linéaire
model = LinearRegression()

# Entraîner le modèle sur les données d'entraînement
model.fit(X_train, y_train)

# Faire des prédictions sur l'ensemble de test
predictions = model.predict(X_test)

# Calculer l'erreur quadratique moyenne (RMSE) pour évaluer les prédictions
rmse = mean_squared_error(y_test, predictions, squared=False)
print("RMSE:", rmse)
# Out:
# RMSE: 0.4234513464599735

# %%
def backtest(df6, model, predictions, start=2, step=1):
    all_predictions = []

    seasons = sorted(df6["season"].unique())

    for i in range(start, len(seasons), step):
        season = seasons[i]

        train = df6[df6["season"] < season]
        test = df6[df6["season"] == season]

        model.fit(train[predictions], train["target"])
        preds = model.predict(test[predictions])
        preds = pd.Series(preds, index=test.index)

        combined = pd.concat([test["target"], preds],axis=1)
        combined.columns = ["actual", "prediction"]

        all_predictions.append(combined)
        return pd.concat(all_predictions)

# %%
from sklearn.metrics import accuracy_score

predictions = predictions[predictions["actual" !=2]]
accuracy_score(predictions["actual"], predictions["predictions"])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[533], line 3
#       1 from sklearn.metrics import accuracy_score
# ----> 3 predictions = predictions[predictions["actual" !=2]]
#       4 accuracy_score(predictions["actual"], predictions["predictions"])
#
# IndexError: arrays used as indices must be of integer (or boolean) type
